# %%
#import relevant packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import urllib.parse
import networkx as nx

# %%
df_accidents_2018 = pd.read_json("https://data.sfgov.org/resource/ubvf-ztfx.json?accident_year=2018&$limit=50000")
df_accidents_2018
# Out:
#       unique_id  cnn_intrsctn_fkey  cnn_sgmt_fkey  case_id_pkey  tb_latitude  \
# 0         27187           30734000      8742101.0     180957642    37.789275
# 1         18115           25876000      4007000.0     180168667    37.768971
# 2         15846           24311000       406000.0     180246031    37.777348
# 3         39327           33576000       445000.0     180405306    37.747208
# 4         13682           24349000      5685000.0     180480790    37.770016
# ...         ...                ...            ...           ...          ...
# 3302       8415           23953000     10672000.0     180021009    37.752495
# 3303       6103           23633000            NaN     180977418    37.749746
# 3304       3096           20188000      7072000.0     180195080    37.733809
# 3305       3364           20660000            NaN     180328532    37.735591
# 3306       6161           23634000      1414000.0     180233997    37.752283
#
# ...

# %%
#API limitations so pull twice
df_accidents_2023 = pd.read_json("https://data.sfgov.org/resource/ubvf-ztfx.json?accident_year=2023&$limit=50000")
df_accidents_2023
# Out:
#       unique_id  cnn_intrsctn_fkey  case_id_pkey  tb_latitude  tb_longitude  \
# 0         74803         24545000.0     230607400    37.790827   -122.390012
# 1         74816         24262000.0     230603088    37.776746   -122.407842
# 2         74628         30753000.0     230104042    37.773036   -122.421941
# 3         74499         24995000.0     230330140    37.794052   -122.407965
# 4         74325         24760000.0     230252641    37.797505   -122.402041
# ...         ...                ...           ...          ...           ...
# 2921      74922         23651000.0     230716493    37.764247   -122.390066
# 2922      75038         25139000.0     230636459    37.785026   -122.414505
# 2923      74893         26049000.0     230716421    37.781151   -122.433959
# 2924      74933         26340000.0     230753542    37.770424   -122.443666
# 2925      76113         25210000.0     230543854    37.788699   -122.420307
#
# ...

# %%
df_accidents = pd.concat([df_accidents_2018, df_accidents_2023], ignore_index=True)
df_accidents
# Out:
#       unique_id  cnn_intrsctn_fkey  cnn_sgmt_fkey  case_id_pkey  tb_latitude  \
# 0         27187         30734000.0      8742101.0     180957642    37.789275
# 1         18115         25876000.0      4007000.0     180168667    37.768971
# 2         15846         24311000.0       406000.0     180246031    37.777348
# 3         39327         33576000.0       445000.0     180405306    37.747208
# 4         13682         24349000.0      5685000.0     180480790    37.770016
# ...         ...                ...            ...           ...          ...
# 6228      74922         23651000.0      8714000.0     230716493    37.764247
# 6229      75038         25139000.0      8242000.0     230636459    37.785026
# 6230      74893         26049000.0     12130000.0     230716421    37.781151
# 6231      74933         26340000.0      6617000.0     230753542    37.770424
# 6232      76113         25210000.0            NaN     230543854    37.788699
#
# ...

# %%
df_accidents_subset = df_accidents[['lighting', 'accident_year', 'type_of_collision', 'collision_severity', 'dph_col_grp_description', 'road_cond_1', 'party1_move_pre_acc']]
df_accidents_subset
# Out:
#                   lighting  accident_year   type_of_collision  \
# 0                 Daylight           2018          Overturned
# 1                 Daylight           2018               Other
# 2                 Daylight           2018           Sideswipe
# 3                 Daylight           2018               Other
# 4                 Daylight           2018             Head-On
# ...                    ...            ...                 ...
# 6228              Daylight           2023           Broadside
# 6229            Not Stated           2023          Not Stated
# 6230              Daylight           2023  Vehicle/Pedestrian
# 6231              Daylight           2023           Broadside
# 6232  Dark - Street Lights           2023            Rear End
#
#               collision_severity   dph_col_grp_description  \
# 0         Injury (Other Visible)              Bicycle Only
# 1         Injury (Other Visible)              Bicycle Only
# ...

# %%
# Create a directed graph
graph = nx.DiGraph()

# Define the relationships
relationships = [
    ('lighting', 'type_of_collision'),
    ('type_of_collision', 'collision_severity'),
    ('dph_col_grp_description', 'type_of_collision'),
    ('road_cond_1', 'type_of_collision'),
    ('road_cond_1', 'party1_move_pre_acc')
]

# Add edges to the graph
for source, target in relationships:
  if source in df_accidents.columns and target in df_accidents.columns:
    graph.add_edge(source, target)

# Print the graph's nodes and edges (optional)
print("Nodes:", graph.nodes())
print("Edges:", graph.edges())
# Out:
# Nodes: ['lighting', 'type_of_collision', 'collision_severity', 'dph_col_grp_description', 'road_cond_1', 'party1_move_pre_acc']
# Edges: [('lighting', 'type_of_collision'), ('type_of_collision', 'collision_severity'), ('dph_col_grp_description', 'type_of_collision'), ('road_cond_1', 'type_of_collision'), ('road_cond_1', 'party1_move_pre_acc')]

# %%
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(graph)  # You can try different layout algorithms
nx.draw(graph, pos, with_labels=True, node_color='skyblue', node_size=1500, edge_color='gray', font_size=10)
plt.title("Graph of Relationships Between Accident Variables")
plt.show()

# %%
# !pip install dowhy
import dowhy
from dowhy import gcm
causal_model = gcm.StructuralCausalModel(graph)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.4/383.4 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.5/174.5 kB 11.2 MB/s eta 0:00:00
# ...

# %%
gcm.auto.assign_causal_mechanisms(causal_model, df_accidents_subset)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(

# %%
gcm.fit(causal_model, df_accidents_subset)
# Out:
# Fitting causal mechanism of node party1_move_pre_acc: 100%|██████████| 6/6 [00:08<00:00,  1.43s/it]

# %%
auto_assignment_summary = gcm.auto.assign_causal_mechanisms(causal_model, df_accidents_subset)
print(auto_assignment_summary)
# Out:
# When using this auto assignment function, the given data is used to automatically assign a causal mechanism to each node. Note that causal mechanisms can also be customized and assigned manually.
# The following types of causal mechanisms are considered for the automatic selection:
#
# If root node:
# An empirical distribution, i.e., the distribution is represented by randomly sampling from the provided data. This provides a flexible and non-parametric way to model the marginal distribution and is valid for all types of data modalities.
#
# If non-root node and the data is continuous:
# Additive Noise Models (ANM) of the form X_i = f(PA_i) + N_i, where PA_i are the parents of X_i and the unobserved noise N_i is assumed to be independent of PA_i.To select the best model for f, different regression models are evaluated and the model with the smallest mean squared error is selected.Note that minimizing the mean squared error here is equivalent to selecting the best choice of an ANM.
#
# ...

# %%
print(gcm.evaluate_causal_model(causal_model, df_accidents_subset))
# Out:
# ...
# Test permutations of given graph: 100%|██████████| 50/50 [00:27<00:00,  1.83it/s]
# Evaluated the performance of the causal mechanisms and the invertibility assumption of the causal mechanisms and the overall average KL divergence between generated and observed distribution and the graph structure. The results are as follows:
#
# ==== Evaluation of Causal Mechanisms ====
# The used evaluation metrics are:
# - KL divergence (only for root-nodes): Evaluates the divergence between the generated and the observed distribution.
# - Mean Squared Error (MSE): Evaluates the average squared differences between the observed values and the conditional expectation of the causal mechanisms.
# - Normalized MSE (NMSE): The MSE normalized by the standard deviation for better comparison.
# - R2 coefficient: Indicates how much variance is explained by the conditional expectations of the mechanisms. Note, however, that this can be misleading for nonlinear relationships.
# ...

# %%
samples = gcm.interventional_samples(causal_model,
                                     {'type_of_collision': lambda y: 'Sideswipe' },
                                     num_samples_to_draw=1000)
print(samples)
# Out:
#                  lighting   dph_col_grp_description           road_cond_1  \
# 0    Dark - Street Lights  Vehicle(s) Only Involved  No Unusual Condition
# 1                Daylight  Vehicle(s) Only Involved  No Unusual Condition
# 2                Daylight        Vehicle-Pedestrian  No Unusual Condition
# 3    Dark - Street Lights  Vehicle(s) Only Involved  No Unusual Condition
# 4    Dark - Street Lights           Vehicle-Bicycle  No Unusual Condition
# ..                    ...                       ...                   ...
# 995              Daylight  Vehicle(s) Only Involved  No Unusual Condition
# 996              Daylight  Vehicle(s) Only Involved  No Unusual Condition
# 997              Daylight           Vehicle-Bicycle  No Unusual Condition
# 998              Daylight  Vehicle(s) Only Involved  No Unusual Condition
# 999              Daylight  Vehicle(s) Only Involved  No Unusual Condition
#
#     type_of_collision         party1_move_pre_acc          collision_severity
# ...

# %%
import numpy as np

# Note: The percentage conversion only makes sense for purely positive attributions.
def convert_to_percentage(value_dictionary):
    total_absolute_sum = np.sum([abs(v) for v in value_dictionary.values()])
    return {k: abs(v) / total_absolute_sum * 100 for k, v in value_dictionary.items()}


arrow_strengths = gcm.arrow_strength(causal_model, target_node='type_of_collision')

# %%
print(arrow_strengths)
# Out:
# {('dph_col_grp_description', 'type_of_collision'): 1.3635364260210574, ('lighting', 'type_of_collision'): 0.054515452958909714, ('road_cond_1', 'type_of_collision'): 0.045690445708011326}

# %%
from dowhy.utils import plot

plot(graph,
     causal_strengths=convert_to_percentage(arrow_strengths),
     figure_size=[15, 10])
